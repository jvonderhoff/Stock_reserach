# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
SP = wb.DataReader('^GSPC', data_source='yahoo', start='2020-1-1')
PENN = wb.DataReader('PENN', data_source='yahoo', start='2020-1-1')

# %%
SP.head()
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2020-01-02  3258.139893  3235.530029  3244.669922  3257.850098  3458250000
# 2020-01-03  3246.149902  3222.340088  3226.360107  3234.850098  3461290000
# 2020-01-06  3246.840088  3214.639893  3217.550049  3246.280029  3674070000
# 2020-01-07  3244.909912  3232.429932  3241.860107  3237.179932  3420380000
# 2020-01-08  3267.070068  3236.669922  3238.590088  3253.050049  3720890000
#
#               Adj Close
# Date
# 2020-01-02  3257.850098
# 2020-01-03  3234.850098
# 2020-01-06  3246.280029
# 2020-01-07  3237.179932
# 2020-01-08  3253.050049

# %%
SP.tail()
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2020-05-20  2980.290039  2953.629883  2953.629883  2971.610107  4992970000
# 2020-05-21  2978.500000  2938.570068  2969.949951  2948.510010  4966940000
# 2020-05-22  2956.760010  2933.590088  2948.050049  2955.449951  3952800000
# 2020-05-26  3021.719971  2988.169922  3004.080078  2991.770020  5837060000
# 2020-05-27  3036.250000  2969.750000  3015.649902  3036.129883  3625890938
#
#               Adj Close
# Date
# 2020-05-20  2971.610107
# 2020-05-21  2948.510010
# 2020-05-22  2955.449951
# 2020-05-26  2991.770020
# 2020-05-27  3036.129883

# %%
mydata = ['High', 'Low', 'Open', 'Close', 'Adj Close']
volumecalc = SP.Volume / 10000

# %%
print(volumecalc)
# Out:
# Date
# 2020-01-02    345825.0000
# 2020-01-03    346129.0000
# 2020-01-06    367407.0000
# 2020-01-07    342038.0000
# 2020-01-08    372089.0000
#                  ...
# 2020-05-20    499297.0000
# 2020-05-21    496694.0000
# 2020-05-22    395280.0000
# 2020-05-26    583706.0000
# 2020-05-27    362589.0938
# Name: Volume, Length: 101, dtype: float64

# %%
SP[mydata].plot(figsize=(10, 7))
plt.show()

# %%
SP['Adj Close'].plot(figsize=(10, 7))
plt.grid()
plt.show()
SP['Adj Close'].plot(figsize=(10, 7))
plt.grid()
plt.show()

# %%
#SP['Adj Close'].plot(figsize=(10, 7))
plt.plot(SP.Volume, 'g')
plt.grid()
plt.show()
SP['Volume'].plot(figsize=(10, 7))
plt.grid()
plt.show()

# %%
SP['Open'].plot(figsize=(8, 5))
plt.show()

# %%
SP['Close'].plot(figsize=(8, 5))
plt.show()

# %%
SP['Adj Close'].plot(figsize=(8, 5))
plt.show()

# %%
SP['Volume'].plot(figsize=(8, 5))
plt.show()

# %%
print(SP)
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2020-01-02  3258.139893  3235.530029  3244.669922  3257.850098  3458250000
# 2020-01-03  3246.149902  3222.340088  3226.360107  3234.850098  3461290000
# 2020-01-06  3246.840088  3214.639893  3217.550049  3246.280029  3674070000
# 2020-01-07  3244.909912  3232.429932  3241.860107  3237.179932  3420380000
# 2020-01-08  3267.070068  3236.669922  3238.590088  3253.050049  3720890000
# ...                 ...          ...          ...          ...         ...
# 2020-05-20  2980.290039  2953.629883  2953.629883  2971.610107  4992970000
# 2020-05-21  2978.500000  2938.570068  2969.949951  2948.510010  4966940000
# 2020-05-22  2956.760010  2933.590088  2948.050049  2955.449951  3952800000
# 2020-05-26  3021.719971  2988.169922  3004.080078  2991.770020  5837060000
# 2020-05-27  3036.250000  2969.750000  3015.649902  3036.129883  3625890938
#
#               Adj Close
# Date
# 2020-01-02  3257.850098
# ...
